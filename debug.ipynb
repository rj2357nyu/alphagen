# %%
import pandas as pd

# %%
df = pd.read_csv('data_news/combined_headlines.csv')

# %%
df.head()
# Out:
#    year  month  day                                          Headlines  \
# 0  2017     12   17  Peter Preston on press and broadcasting  \n\n\...
# 1  2017     12   17  Why business could prosper under a Corbyn gove...
# 2  2017     12   17  Youngest staff to be given UK workplace pensio...
# 3  2017     12   17  Grogonomics  \n\n\n  This year has been about ...
# 4  2017     12   17  Butchers carve out a niche as UK shoppers opt ...
#
#      source
# 0  Guardian
# 1  Guardian
# 2  Guardian
# 3  Guardian
# 4  Guardian

# %%
df_sentiment = pd.read_csv('data_news/headlines_with_sentiment.csv')

# %%
df_sentiment.head(20)
# Out:
#     year  month  day                                          Headlines  \
# 0   2017     12   17  Peter Preston on press and broadcasting  \n\n\...
# 1   2017     12   17  Why business could prosper under a Corbyn gove...
# 2   2017     12   17  Youngest staff to be given UK workplace pensio...
# 3   2017     12   17  Grogonomics  \n\n\n  This year has been about ...
# 4   2017     12   17  Butchers carve out a niche as UK shoppers opt ...
# 5   2017     12   17  David Cameron to lead £750m UK-China investmen...
# 6   2017     12   17  US mall operators must buy into e-retail and n...
# 7   2017     12   17  Global shopping centre giants go on a Christma...
# 8   2017     12   17  Is the global desire to buy British a bad thin...
# 9   2017     12   17  Alabama unions see Doug Jones's win as a victo...
# 10  2017     12   17  Britons set new gin record after buying 47m bo...
# 11  2017     12   17  British Steel pension scheme members ‘preyed o...
# ...

# %%
df_sentiment[df_sentiment['year'] == 2019 and df_sentiment['month'] == 1 ]
